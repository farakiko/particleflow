# %%
PATH = "../data/muoncollider/mlpf/ttbar/ttbar_reco_0_edm4hep.root"
PATH2 = "../data/reco_p8_ee_tt_ecm365_0.root"

# %%
import uproot
import numpy as np

# %%
fi = uproot.open(PATH)
arrs = fi["events"]

print("number of events per file: ", arrs.num_entries)
# Out:
# number of events per file:  1

# %%
arrs.keys()
# Out:
# ['AllCaloHitContributionsCombined',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.PDG',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.energy',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.time',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.stepPosition.x',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.stepPosition.y',
#  'AllCaloHitContributionsCombined/AllCaloHitContributionsCombined.stepPosition.z',
#  '_AllCaloHitContributionsCombined_particle',
#  '_AllCaloHitContributionsCombined_particle/_AllCaloHitContributionsCombined_particle.index',
#  '_AllCaloHitContributionsCombined_particle/_AllCaloHitContributionsCombined_particle.collectionID',
#  'AllTracks',
#  'AllTracks/AllTracks.type',
#  'AllTracks/AllTracks.chi2',
#  'AllTracks/AllTracks.ndf',
#  'AllTracks/AllTracks.Nholes',
#  'AllTracks/AllTracks.subdetectorHitNumbers_begin',
# ...

# %%
arrs["_MCParticle_daughters"]
# Out:
# <TBranchElement '_MCParticle_daughters' (2 subbranches) at 0x00010a390040>

# %%
fi.get("podio_metadata").keys()
# Out:
# ['metadata___CollectionTypeInfo',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.collectionID',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.dataType',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.isSubset',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.schemaVersion',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.name',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo.storageType',
#  'events___CollectionTypeInfo',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.collectionID',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.dataType',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.isSubset',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.schemaVersion',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.name',
#  'events___CollectionTypeInfo/events___CollectionTypeInfo.storageType',
#  'PodioBuildVersion',
# ...

# %%
for i in fi.get("podio_metadata").arrays("events___CollectionTypeInfo.name")["events___CollectionTypeInfo.name"][0]:
    print(i)
# Out:
# AllCaloHitContributionsCombined
# AllTracks
# AllTracks_dQdx
# ECalBarrelCollection
# EcalBarrelCollectionConed
# EcalBarrelCollectionDigi
# EcalBarrelCollectionRec
# EcalBarrelCollectionSel
# EcalBarrelRelationsSimConed
# EcalBarrelRelationsSimDigi
# EcalBarrelRelationsSimRec
# EcalBarrelRelationsSimSel
# ECalEndcapCollection
# EcalEndcapCollectionConed
# EcalEndcapCollectionDigi
# EcalEndcapCollectionRec
# EcalEndcapCollectionSel
# EcalEndcapRelationsSimConed
# EcalEndcapRelationsSimDigi
# EcalEndcapRelationsSimRec
# EcalEndcapRelationsSimSel
# EventHeader
# HCalBarrelCollection
# HcalBarrelCollectionConed
# HcalBarrelCollectionDigi
# HcalBarrelCollectionRec
# HcalBarrelCollectionSel
# HcalBarrelRelationsSimConed
# HcalBarrelRelationsSimDigi
# HcalBarrelRelationsSimRec
# HcalBarrelRelationsSimSel
# HCalEndcapCollection
# HcalEndcapCollectionConed
# HcalEndcapCollectionDigi
# HcalEndcapCollectionRec
# HcalEndcapCollectionSel
# HcalEndcapRelationsSimConed
# ...

# %%
fi2 = uproot.open(PATH2)
arrs2 = fi2["events"]

fi2.get("podio_metadata").keys()
# Out:
# ['metadata___idTable',
#  'metadata___idTable/m_collectionIDs',
#  'metadata___idTable/m_names',
#  'metadata___CollectionTypeInfo',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo._3',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo._2',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo._1',
#  'metadata___CollectionTypeInfo/metadata___CollectionTypeInfo._0',
#  'configuration_metadata___idTable',
#  'configuration_metadata___idTable/m_collectionIDs',
#  'configuration_metadata___idTable/m_names',
#  'configuration_metadata___CollectionTypeInfo',
#  'configuration_metadata___CollectionTypeInfo/configuration_metadata___CollectionTypeInfo._3',
#  'configuration_metadata___CollectionTypeInfo/configuration_metadata___CollectionTypeInfo._2',
#  'configuration_metadata___CollectionTypeInfo/configuration_metadata___CollectionTypeInfo._1',
#  'configuration_metadata___CollectionTypeInfo/configuration_metadata___CollectionTypeInfo._0',
# ...

# %%
arrs["AllCaloHitContributionsCombined"].array()[0:5]
# Out:
# <Array [... -1.44e+03, -1.44e+03]}] type='1 * {"AllCaloHitContributionsCombined....'>

# %%
arrs2["CalohitMCTruthLink"].array()
# Out:
# <Array [{'CalohitMCTruthLink.weight': [, ... ] type='100 * {"CalohitMCTruthLink....'>

# %%
fi.get("podio_metadata").arrays("events___CollectionTypeInfo.name")["events___CollectionTypeInfo.name"][0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fi.get("podio_metadata").arrays("events___CollectionTypeInfo.name")["events___CollectionTypeInfo.name"][0]["AllCaloHitContributionsCombined"]
#
# File ~/miniconda3/envs/coffea-env/lib/python3.9/site-packages/awkward/highlevel.py:991, in Array.__getitem__(self, where)
#     579 """
#     580 Args:
#     581     where (many types supported; see below): Index of positions to
#    (...)
#     988 have the same dimension as the array being indexed.
#     989 """
#     990 if not hasattr(self, "_tracers"):
# --> 991     tmp = ak._util.wrap(self.layout[where], self._behavior)
#     992 else:
#     993     tmp = ak._connect._jax.jax_utils._jaxtracers_getitem(self, where)
#
# ValueError: cannot slice NumpyArray by field name
#
# ...

# %%
for i in fi2.get("podio_metadata").arrays("events___idTable/m_names")["events___idTable/m_names"][0]:
    print(i)
# Out:
# EventHeader
# MCParticles
# InnerTrackerBarrelCollection
# InnerTrackerEndcapCollection
# OuterTrackerBarrelCollection
# OuterTrackerEndcapCollection
# VertexBarrelCollection
# VertexEndcapCollection
# ECalBarrelCollection
# ECalBarrelCollectionContributions
# ECalEndcapCollection
# ECalEndcapCollectionContributions
# HCalBarrelCollection
# HCalBarrelCollectionContributions
# HCalEndcapCollection
# HCalEndcapCollectionContributions
# HCalRingCollection
# HCalRingCollectionContributions
# LumiCalCollection
# LumiCalCollectionContributions
# YokeBarrelCollection
# YokeBarrelCollectionContributions
# YokeEndcapCollection
# YokeEndcapCollectionContributions
# BuildUpVertices
# BuildUpVertices_associatedParticles
# BuildUpVertices_RP
# BuildUpVertices_RP_startVertices
# BuildUpVertices_V0
# BuildUpVertices_V0_associatedParticles
# BuildUpVertices_V0_RP
# BuildUpVertices_V0_RP_startVertices
# ECALBarrel
# ECALEndcap
# HCALBarrel
# HCALEndcap
# HCALOther
# ITrackerEndcapHits
# ITrackerHits
# ...

# %%
for i in fi2.get("podio_metadata").arrays("events___idTable/m_collectionIDs")["events___idTable/m_collectionIDs"][0]:
    print(i)
# Out:
# 3616779153
# 2714477136
# 4118038771
# 1836205715
# 138199101
# 340844528
# 2246476560
# 1524465474
# 1082044795
# 75357852
# 201957718
# 2470584824
# 1840200513
# 1146136818
# 1356401389
# 2191725667
# 2910502858
# 995571814
# 1165332501
# 3669141454
# 2545921446
# 1578098675
# 1612748112
# 1760973346
# 4244895184
# 3187643792
# 822742788
# 145332306
# 2613598224
# 896992784
# 2109262263
# 3312417931
# 1265367388
# 2257282296
# 124629188
# 1286131593
# 1000433565
# 1439163379
# 845410443
# 1407865691
# 4154871912
# 1306104674
# 3039846669
# 255155955
# 3776498247
# 975445999
# 450524680
# 4196981182
# 2271775733
# 3136518664
# 213204910
# 1351041417
# 2605319205
# 3993651223
# 3362871859
# 2195150269
# 349086238
# 3499419678
# 753091896
# 4103437050
# 1807982628
# 3917967182
# 3678648449
# 3392576173
# 30812586
# 1100348767
# 3298356749
# 161122071
# 1438540318
# 3160275263
# 380785324
# 2414353170
# 427361438
# 1564637371
# 1604833171
# 288527677
# 3799154064
# 43770259
# ...

# %%
fi.get("metadata").arrays("CollectionIDs")["CollectionIDs"]["m_names"][0],

# %%
iev = 0   # select the first event
print("number of particles per event:", len(arrs["MCParticle/MCParticle.PDG"].array()[0]))
# Out:
# number of particles per event: 125752

# %%
X = np.unique(abs(arrs["MCParticle/MCParticle.PDG"].array()[0]).to_numpy(), return_counts=True)

for i in range(len(X[0])):
    print(f"PID: {X[0][i]}, instances: {X[1][i]}")
# Out:
# PID: 1, instances: 33
# PID: 2, instances: 16
# PID: 3, instances: 13
# PID: 4, instances: 8
# PID: 5, instances: 8
# PID: 6, instances: 14
# PID: 11, instances: 66278
# PID: 12, instances: 81
# PID: 13, instances: 20
# PID: 14, instances: 24
# PID: 21, instances: 243
# PID: 22, instances: 57345
# PID: 24, instances: 3
# PID: 111, instances: 109
# PID: 113, instances: 6
# PID: 130, instances: 11
# PID: 211, instances: 179
# PID: 213, instances: 15
# PID: 221, instances: 14
# PID: 223, instances: 10
# PID: 310, instances: 9
# PID: 311, instances: 17
# PID: 313, instances: 2
# PID: 321, instances: 14
# PID: 323, instances: 6
# PID: 331, instances: 4
# PID: 333, instances: 1
# PID: 411, instances: 3
# PID: 431, instances: 1
# PID: 433, instances: 1
# PID: 511, instances: 1
# PID: 513, instances: 1
# PID: 531, instances: 1
# PID: 533, instances: 1
# PID: 1114, instances: 2
# PID: 2112, instances: 739
# PID: 2212, instances: 233
# PID: 2214, instances: 1
# PID: 3112, instances: 1
# ...
